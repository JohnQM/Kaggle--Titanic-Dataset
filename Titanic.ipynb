# %%
# Import Titanic datasets, including train data
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
train = pd.read_csv("/content/sample_data/train.csv")

# %%
train
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
train.shape
# Out:
# (891, 12)

# %%
sns.set_style("dark")
plt.figure(figsize=(8, 8))
sns.boxplot(data=train);
plt.title("Train Dataset", fontsize=15)
plt.show()

# %%
sns.set_style('whitegrid')
ax1 = sns.boxplot(x="Embarked", y="Fare", hue="Pclass", data=train, ax = ax[0]);
plt.figure(figsize=(8, 8))
ax1.set_title("Training Set", fontsize = 18)
sns.boxplot(data=train, palette="deep")
plt.title("Train Dataset")
sns.despine(left=True)

# %%
pal = {1:"orange", 0:"gray"}
sns.set(style="darkgrid")
plt.subplots(figsize = (12,8))
ax = sns.countplot(x = "Pclass", 
                   hue="Survived",
                   data = train, 
                   linewidth=4, 
                   palette = pal
)

## Fixing title, xlabel and ylabel
plt.title("Passenger Pclass Distribution (Survived and Non-Survived)", fontsize = 18, pad=40)
plt.xlabel("Pclass", fontsize = 15);
plt.ylabel("# of Passenger Survived", fontsize = 15)

## Fixing legends
leg = ax.get_legend()
leg.set_title("Survived")
legs = leg.texts
legs[0].set_text("No")
legs[1].set_text("Yes")
plt.show()

# %%
pal = {1:"lightblue", 0:"lightgreen"}
sns.set(style="darkgrid")
plt.subplots(figsize = (12,8))
ax = sns.countplot(x = "Embarked", 
                   hue="Survived",
                   data = train, 
                   linewidth=4, 
                   palette = pal
)

## Fixing title, xlabel and ylabel
plt.title("Passenger Embarked Distribution (Survived and Non-Survived)", fontsize = 18, pad=40)
plt.xlabel("Embarked", fontsize = 15);
plt.ylabel("# of Passenger Survived", fontsize = 15)

## Fixing xticks
#labels = ['Female', 'Male']
#plt.xticks(sorted(train.Sex.unique()), labels)

## Fixing legends
leg = ax.get_legend()
leg.set_title("Survived")
legs = leg.texts
legs[0].set_text("No")
legs[1].set_text("Yes")
plt.show()

# %%
# fig = plt.figure(figsize=(15,8),)
# ax=sns.kdeplot(train.loc[(train['Survived'] == 0),'Fare'] , color='gray',shade=True,label='not survived')
# ax=sns.kdeplot(train.loc[(train['Survived'] == 1),'Fare'] , color='g',shade=True, label='survived')
# plt.title('Fare Distribution Survived vs Non Survived', fontsize = 18, pad = 40)
# plt.ylabel("Frequency of Passenger Survived", fontsize = 15, labelpad = 20)
# plt.xlabel("Fare", fontsize = 15, labelpad = 20);

# %%
fig = plt.figure(figsize=(12,8),)
ax=sns.kdeplot(train.loc[(train['Survived'] == 0),'Age'] , color='orange',shade=True,label='not survived')
ax=sns.kdeplot(train.loc[(train['Survived'] == 1),'Age'] , color='red',shade=False, label='survived')
plt.title('Age Distribution (Survived and Non-Survived)', fontsize = 18, pad = 40)
plt.xlabel("Age", fontsize = 13, labelpad = 25)
plt.ylabel('', fontsize = 13, labelpad= 25);
